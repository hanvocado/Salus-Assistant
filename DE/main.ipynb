# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
import time, os, re
from azure_helper import upload_img_by_url
from dotenv import load_dotenv
import pandas as pd

# %%
load_dotenv()
azure_url = os.getenv('AZURE_STORAGE_URL')

chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-gpu")
driver = webdriver.Chrome(options=chrome_options)
driver.implicitly_wait(10)
# Out:
# The chromedriver version (133.0.6943.141) detected in PATH at C:\WebDriver\chromedriver.exe might not be compatible with the detected chrome version (134.0.6998.178); currently, chromedriver 134.0.6998.165 is recommended for chrome 134.*, so it is advised to delete the driver in PATH and retry

# %%
def crawl_img_url(item):
    print(f"Searching image for: {item}")
    driver.get("https://images.google.com/")
    search_box = driver.find_element(By.NAME, "q")
    search_box.clear()
    search_box.send_keys(item)
    search_box.send_keys(Keys.RETURN)
    time.sleep(2)

    main_images_div = driver.find_element(By.ID, "rcnt")

    # Sometimes it raise SSL eror so I write code to pass and try another link
    images_holders = main_images_div.find_elements(By.CSS_SELECTOR, "img.YQ4gaf")
    url = None
    for holder in images_holders:
        try:
            holder.click() 
            time.sleep(5)
            url = driver.find_element(By.CSS_SELECTOR, "img.sFlh5c.FyHeAf.iPVvYb, img.sFlh5c.FyHeAf").get_attribute("src")
            if url is not None:
                break
        except Exception:
            pass

    return url

# %%
def scrape_food_info():
    url = os.getenv('FOOD_NUTRITION_WEBSITE')
    driver.get(url)
    rows = driver.find_elements(By.CLASS_NAME, 'row-render')
    food_list = []
    for row in rows:
        properties = row.find_elements(By.TAG_NAME, 'td')

        food = {
            'food_name': properties[0].text.strip(),
            'serving_size': properties[1].text.strip(),
            'calories': properties[2].text.strip(),
            'fat': properties[3].text.strip(),
            'sugar': properties[4].text.strip(),
            'protein': properties[5].text.strip(),
            'fiber': properties[6].text.strip()
        }
        food_list.append(food)

    return food_list

# %%
def save_as_csv(list_of_item):
    df = pd.DataFrame(list_of_item)
    df.to_csv('food_data.csv', index=False)

# %%
def clean_name(name):
    name_without_space = name.replace(' ', '_')
    name_with_word_only = re.sub(r'\W+', '', name_without_space)
    return name_with_word_only

# %%
food_list = scrape_food_info()
print('Done scrape food info')
for food in food_list:
    attempts = 3
    external_src = None
    while (external_src is None and attempts > 0):
        external_src = crawl_img_url(food['food_name'])
        attempts -= 1

    food['img_src'] = external_src
# Out:
# Done scrape food info
# Searching image for: Gỏi cuốn tôm thịt
# Searching image for: Bánh mì thịt nướng
# Searching image for: Bún đậu mắm tôm
# Searching image for: Bún chả Hà Nội
# Searching image for: Mì xào Bò
# Searching image for: Sữa tươi trân châu đường đen
# Searching image for: Trà Sữa
# Searching image for: KimBap
# Searching image for: Trứng vịt lộn
# Searching image for: Củ sắn
# Searching image for: Mận đỏ
# Searching image for: Thanh long
# Searching image for: Ổi
# Searching image for: Vú sữa
# Searching image for: Mít sấy
# Searching image for: Chuối sấy
# Searching image for: Cam
# Searching image for: Đậu phộng chiên muối
# Searching image for: Đậu phộng rang
# Searching image for: Sơ ri
# Searching image for: Nho ta (tím)
# Searching image for: Hồng đỏ
# Searching image for: Đu đủ
# Searching image for: Đậu phộng da cá
# Searching image for: Đậu phộng nấu
# Searching image for: Khoai lang chiên
# Searching image for: Khoai tây
# Searching image for: Khế
# Searching image for: Mãng cầu xiêm
# Searching image for: Bắp nướng
# Searching image for: Bắp luộc
# Searching image for: Táo tây
# Searching image for: Khoai mì
# Searching image for: Khoai từ
# Searching image for: Lê
# Searching image for: Bắp xào
# Searching image for: Khoai lang
# Searching image for: Bưởi
# Searching image for: Mãng cầu ta
# Searching image for: Dưa hấu
# Searching image for: Chuối già
# Searching image for: Khoai môn
# Searching image for: Nho Mỹ (đỏ/xanh)
# Searching image for: Cóc
# Searching image for: Nho khô
# Searching image for: Quýt
# Searching image for: Hạt điều
# Searching image for: Chuối khô
# Searching image for: Sầu riêng
# Searching image for: Măng cụt
# Searching image for: Chôm chôm
# Searching image for: Vải đóng hộp
# Searching image for: Mít nghệ
# Searching image for: Mít tố nữ
# Searching image for: Táo ta
# Searching image for: Nhãn thường
# Searching image for: Nhãn tiêu
# Searching image for: Xoài
# Searching image for: Thơm
# Searching image for: Chuối sứ
# Searching image for: Chuối cau
# Searching image for: Bơ
# Searching image for: Trái dừa tươi
# Searching image for: Thạch dừa
# Searching image for: Sữa hộp Cô gái Hà lan
# Searching image for: Sữa đậu nành Tribeco
# Searching image for: Sữa đặc có đường
# Searching image for: Sữa chua Yoghurt Vinamilk
# Searching image for: Sữa chua uống Yo-Most
# Searching image for: Sinh tố
# Searching image for: Phô mai Bò cười
# Searching image for: Nước sâm
# Searching image for: Nước rau má
# Searching image for: Nước ngọt có gaz
# Searching image for: Nước mía
# Searching image for: Nước ép trái cây đóng hộp
# Searching image for: Nước chanh
# Searching image for: Nước cam vắt
# Searching image for: Kem hộp
# Searching image for: Kem Cornetto
# Searching image for: Kem cây Kido/Wall
# Searching image for: Chôm chôm đóng hộp
# Searching image for: Cocktail trái cây
# Searching image for: Cà phê sữa gói tan
# Searching image for: Cà phê đen phin
# Searching image for: Bia
# Searching image for: Trứng vịt luộc
# Searching image for: Trứng vịt bắc thảo
# Searching image for: Trứng gà ta
# Searching image for: Trứng gà Mỹ
# Searching image for: Trứng cút
# Searching image for: Hột vịt muối
# Searching image for: Hột vịt lộn
# Searching image for: Xôi vò
# Searching image for: Xôi vị
# Searching image for: Xôi nếp than
# Searching image for: Xôi mặn
# Searching image for: Xôi lá cẩm
# Searching image for: Xôi khúc (cúc)
# Searching image for: Xôi gấc
# Searching image for: Xôi đậu xanh
# Searching image for: Xôi đậu phộng
# Searching image for: Xôi đậu đen
# Searching image for: Xôi bắp
# Searching image for: Sâm bổ lượng
# Searching image for: Chè trôi nước
# Searching image for: Chè thưng
# Searching image for: Chè thạch nhãn
# Searching image for: Chè táo xọn
# Searching image for: Chè nếp khoai môn
# Searching image for: Chè nếp đậu trắng
# Searching image for: Chè đậu xanh phổ tai
# Searching image for: Chè đậu xanh đánh
# Searching image for: Chè đậu trắng
# Searching image for: Chè đậu đen
# Searching image for: Chè chuối chưng
# Searching image for: Chè bắp
# Searching image for: Bắp giã
# Searching image for: Kẹo trái cây
# Searching image for: Kẹo sữa
# Searching image for: Kẹo dừa
# Searching image for: Kẹo dẻo
# Searching image for: Kẹo chocolate nhân đậu phộng
# Searching image for: Há cảo
# Searching image for: Giò cháo quẩy
# Searching image for: Bánh xèo
# Searching image for: Bánh ướt
# Searching image for: Bánh tiêu
# Searching image for: Bánh tét nhân mặn
# Searching image for: Bánh tét nhân đậu ngọt
# Searching image for: Bánh tét nhân chuối
# Searching image for: Bánh sừng trâu
# Searching image for: Bánh su kem
# Searching image for: Bánh snack
# Searching image for: Bánh quy bơ (biscuit)
# Searching image for: Bánh phồng tôm
# Searching image for: Bánh patechaud
# Searching image for: Bánh mì thịt
# Searching image for: Bánh mì sandwich kẹp thịt
# Searching image for: Bánh mì sandwich
# Searching image for: Bánh mì ổ
# Searching image for: Bánh mì ngọt Đức phát
# Searching image for: Bánh mì kẹp chả lụa
# Searching image for: Bánh mì kẹp chà bông
# Searching image for: Bánh mì kẹp cá hộp
# Searching image for: Bánh mì cadé Kinh đô
# Searching image for: Bánh men
# Searching image for: Bánh mè
# Searching image for: Bánh lá dừa nhân đậu
# Searching image for: Bánh lá dứa nhân chuối
# Searching image for: Bánh lá chả tôm
# Searching image for: Bánh khọt
# Searching image for: Bánh khoai mì nướng
# Searching image for: Bánh ít nhân đậu
# Searching image for: Bánh ít nhân dừa
# Searching image for: Bánh giò
# Searching image for: Bánh Flan
# Searching image for: Bánh đậu xanh nướng
# Searching image for: Bánh da lợn
# Searching image for: Bánh chưng
# Searching image for: Bánh chuối chiên
# Searching image for: Bánh chuối
# Searching image for: Bánh chocopie
# Searching image for: Bánh cuốn
# Searching image for: Bánh cay
# Searching image for: Bánh bột lọc
# Searching image for: Bánh bông lan kem vuông
# Searching image for: Bánh bông lan chén
# Searching image for: Bánh bông lan cuốn
# Searching image for: Bánh bò
# Searching image for: Bánh bía
# Searching image for: Bánh bèo thập cẩm
# Searching image for: Bánh bèo (một loại)
# Searching image for: Bánh bao nhân thịt
# Searching image for: Bánh bao nhân cadé
# Searching image for: Phở gà
# Searching image for: Phở bò viên
# Searching image for: Phở bò tái
# Searching image for: Phở bò chín
# Searching image for: Nui thịt heo
# Searching image for: Nui chiên
# Searching image for: Miến gà
# Searching image for: Mì xào dòn
# Searching image for: Mì vịt tiềm
# Searching image for: Mì thịt heo
# Searching image for: Mì quảng
# Searching image for: Hủ tíu xào
# Searching image for: Hủ tíu thịt heo
# Searching image for: Hủ tíu Nam vang
# Searching image for: Hủ tíu mì
# Searching image for: Hủ tíu bò kho
# Searching image for: Hoành thánh
# Searching image for: Cháo lòng
# Searching image for: Cháo huyết
# Searching image for: Cháo gỏi vịt
# Searching image for: Cháo đậu đỏ
# Searching image for: Canh bún
# Searching image for: Bún thịt nướng chả giò
# Searching image for: Bún riêu ốc
# Searching image for: Bún riêu cua
# Searching image for: Bún mộc
# Searching image for: Bún măng
# Searching image for: Bún mắm
# Searching image for: Bún bò huế (giò)
# Searching image for: Bột chiên
# Searching image for: Bánh canh thịt heo
# Searching image for: Bánh canh thịt gà
# Searching image for: Bánh canh giò heo
# Searching image for: Bánh canh cua
# Searching image for: Thịt kho tiêu
# Searching image for: Thịt heo quay
# Searching image for: Tôm sốt cà
# Searching image for: Tôm lăn bột chiên
# Searching image for: Tàu hủ ky chiên
# Searching image for: Sườn ram
# Searching image for: Sườn nướng
# Searching image for: Nấm rơm kho
# Searching image for: Mít kho
# Searching image for: Mì căn xào sả
# Searching image for: Mì bò viên
# Searching image for: Măng kho thập cẩm
# Searching image for: Mắm Thái
# Searching image for: Gỏi ngó sen
# Searching image for: Gỏi bắp chuối
# Searching image for: Đùi gà chiên
# Searching image for: Đậu hủ sốt cà
# Searching image for: Đậu hủ dồn thịt
# Searching image for: Đậu hủ chiên xả
# Searching image for: Chả trứng chưng
# Searching image for: Chả lụa chiên
# Searching image for: Cơm chiên dương châu
# Searching image for: Canh rau ngót
# Searching image for: Canh khổ qua hầm
# Searching image for: Canh kiểm
# Searching image for: Canh chua
# Searching image for: Cà tím nướng
# Searching image for: Cà ri
# Searching image for: Cá mòi kho
# Searching image for: Cà chua dồn thịt
# Searching image for: Cá cơm lăn bột chiên
# Searching image for: Bún xào
# Searching image for: Bún thịt nướng
# Searching image for: Bún riêu
# Searching image for: Bún bò huế
# Searching image for: Bông cải xào thập cẩm
# Searching image for: Bánh bao chay
# Searching image for: Xíu mại
# Searching image for: Thịt kho trứng
# Searching image for: Thịt heo xào giá hẹ
# Searching image for: Thịt heo xào đậu que
# Searching image for: Thịt heo phá lấu
# Searching image for: Thịt bò xào nấm rơm
# Searching image for: Thịt bò xào măng
# Searching image for: Thịt bò xào hành tây
# Searching image for: Thịt bò xào giá hẹ
# Searching image for: Thịt bò xào đậu que
# Searching image for: Thị heo quay
# Searching image for: Tép rang
# Searching image for: Mực xào thập cẩm
# Searching image for: Mực xào sả ớt
# Searching image for: Mắm chưng
# Searching image for: Lạp xưởng chiên
# Searching image for: Khổ qua xào trứng
# Searching image for: Khoai tây bò bít tết
# Searching image for: Gỏi tôm cuốn
# Searching image for: Gỏi khô bò
# Searching image for: Gỏi bì cuốn
# Searching image for: Gan heo xào
# Searching image for: Gà xào sả ớt
# Searching image for: Gà rô ti
# Searching image for: Gà kho gừng
# Searching image for: Chim cút chiên bơ
# Searching image for: Chả lụa kho
# Searching image for: Chả giò chiên
# Searching image for: Chả cá thác lác chiên
# Searching image for: Cơm tấm sườn
# Searching image for: Cơm tấm chả
# Searching image for: Cơm tấm bì
# Searching image for: Canh rau dền
# Searching image for: Canh mướp
# Searching image for: Canh khoai mỡ
# Searching image for: Canh hẹ
# Searching image for: Canh cải ngọt
# Searching image for: Canh bí rợ
# Searching image for: Canh bí đao
# Searching image for: Canh bầu
# Searching image for: Canh bắp cải
# Searching image for: Cá viên kho
# Searching image for: Cá trê chiên
# Searching image for: Cá ngừ kho
# Searching image for: Cá lóc kho
# Searching image for: Cá lóc chiên
# Searching image for: Cá hú kho
# Searching image for: Cá đối kho
# Searching image for: Cá đối chiên
# Searching image for: Cá chim chiên
# Searching image for: Cá chép chưng tương
# Searching image for: Cá bạc má kho
# Searching image for: Cá bạc má chiên
# Searching image for: Bò cuốn mỡ chài
# Searching image for: Bò cuốn lá lốt
# Searching image for: Bò bía
# Searching image for: Bầu xào trứng
# Searching image for: Cơm trắng
# Searching image for: Gạo lứt khô
# Searching image for: Bún gạo lứt khô
# Searching image for: Phở gạo lứt khô
# Searching image for: Hủ tiếu gạo lứt khô
# Searching image for: Nui gạo lứt khô
# Searching image for: Thịt cua nạc
# Searching image for: Thịt cua gạch
# Searching image for: Tôm sú
# Searching image for: Tôm Hùm
# Searching image for: Tôm rang thịt
# Searching image for: Tôm rim
# Searching image for: Tôm rang me chua ngọt
# Searching image for: Gà nướng
# Searching image for: Ức gà
# Searching image for: Gạo trắng
# Searching image for: Cà phê sữa Việt Nam
# Searching image for: Bún tươi
# Searching image for: Bún gạo
# Searching image for: Bánh mì nâu đen
# Searching image for: Vịt luộc - hấp
# Searching image for: Nui xào bò
# Searching image for: Bánh ngô chiên
# Searching image for: Chè thái
# Searching image for: Cá khô chiên
# Searching image for: Cá chỉ vàng
# Searching image for: Cá sặc khô
# Searching image for: Cá lóc khô
# Searching image for: Khô cá dứa
# Searching image for: Chả bò - giò bò
# Searching image for: Bò viên
# Searching image for: Cá viên chiên
# Searching image for: Bánh ú
# Searching image for: Khô gà
# Searching image for: Khô bò
# Searching image for: Khô Heo
# Searching image for: Thịt chó
# Searching image for: Thịt chó rượu mận
# Searching image for: Thịt bò
# Searching image for: Thịt gà
# Searching image for: Thịt heo
# Searching image for: Thịt vịt
# Searching image for: Thịt cừu
# Searching image for: Thịt dê
# Searching image for: Thịt lợn quay
# Searching image for: Thịt thỏ
# Searching image for: Thịt gà tây
# Searching image for: Thịt ngỗng
# Searching image for: Thịt cá hồi
# Searching image for: Thịt cá ngừ
# Searching image for: Thịt cá thu
# Searching image for: Thịt lươn
# Searching image for: Thịt cá rô phi
# Searching image for: Thịt cá trê
# Searching image for: Thịt cá chép
# Searching image for: Thịt cá basa
# Searching image for: Thịt tôm
# Searching image for: Thịt cua
# Searching image for: Thịt ốc
# Searching image for: Thịt bồ câu
# Searching image for: Thịt lạc đà
# Searching image for: Táo
# Searching image for: Chuối
# Searching image for: Dâu tây
# Searching image for: Nho
# Searching image for: Đào
# Searching image for: Kiwi
# Searching image for: Dưa vàng
# Searching image for: Dứa (Thơm)
# Searching image for: Lựu
# Searching image for: Dừa
# Searching image for: Chanh
# Searching image for: Quả mâm xôi
# Searching image for: Quả việt quất
# Searching image for: Mít
# Searching image for: Vải thiều
# Searching image for: Mận
# Searching image for: Hạt hạnh nhân
# Searching image for: Hạt óc chó
# Searching image for: Hạt mắc ca
# Searching image for: Hạt dẻ cười
# Searching image for: Hạt hạt dưa
# Searching image for: Hạt hạt bí
# Searching image for: Hạt thông
# Searching image for: Hạt chia
# Searching image for: Hạt lanh
# Searching image for: Hạt hướng dương
# Searching image for: Hạt phỉ
# Searching image for: Hạt mè (vừng)
# Searching image for: Hạt đậu phộng
# Searching image for: Hạt đậu xanh
# Searching image for: Hạt quinoa
# Searching image for: Cải bó xôi (rau bina)
# Searching image for: Cải xoăn (kale)
# Searching image for: Bông cải xanh
# Searching image for: Cà rốt
# Searching image for: Bắp cải
# Searching image for: Dưa leo (dưa chuột)
# Searching image for: Cà chua
# Searching image for: Đậu xanh
# Searching image for: Măng tây
# Searching image for: Cải thìa (bok choy)
# Searching image for: Rau muống
# Searching image for: Cải ngọt
# Searching image for: Rau đay
# Searching image for: Rau má
# Searching image for: Rau dền
# Searching image for: Củ cải trắng
# Searching image for: Bông cải trắng
# Searching image for: Ớt chuông
# Searching image for: Hành tây
# Searching image for: Củ dền
# Searching image for: Bí ngô
# Searching image for: Bí đỏ
# Searching image for: Bí xanh
# Searching image for: Đậu cô ve
# Searching image for: Mướp đắng
# Searching image for: Mướp hương
# Searching image for: Pizza
# Searching image for: Hamburger
# Searching image for: Hotdog
# Searching image for: Gà rán
# Searching image for: Khoai tây chiên
# Searching image for: Nachos
# Searching image for: Taco
# Searching image for: Burrito
# Searching image for: Sandwich gà
# Searching image for: Cheeseburger
# Searching image for: Bánh mì kẹp thịt nướng
# Searching image for: Bánh sandwich phô mai nướng
# Searching image for: Bánh mì Doner Kebab
# Searching image for: Bánh mì sandwich thịt nguội
# Searching image for: Bánh mì bánh mì xúc xích
# Searching image for: Gà viên chiên
# Searching image for: Mì xào
# Searching image for: Pasta (mì Ý)
# Searching image for: Bánh kếp
# Searching image for: Sushi
# Searching image for: Bánh bao
# Searching image for: Bánh ngọt (cupcake)
# Searching image for: Kem que
# Searching image for: Kem ly
# Searching image for: Bánh rán (donut)
# Searching image for: Bánh waffle
# Searching image for: Chocolate bar
# Searching image for: Nước lọc
# Searching image for: Sữa tươi nguyên chất
# Searching image for: Sữa đậu nành
# Searching image for: Sữa chua uống
# Searching image for: Nước cam ép
# Searching image for: Nước dừa
# Searching image for: Nước ép cà chua
# Searching image for: Nước ép táo
# Searching image for: Nước ép nho
# Searching image for: Nước ép cà rốt
# Searching image for: Trà xanh không đường
# Searching image for: Trà xanh có đường
# Searching image for: Nước ngọt có gaz (cola)
# Searching image for: Nước ngọt không gaz
# Searching image for: Nước tăng lực
# Searching image for: Nước chanh đường
# Searching image for: Nước ép lựu
# Searching image for: Nước ép dưa hấu
# Searching image for: Cà phê đen không đường
# Searching image for: Cà phê sữa
# Searching image for: Sữa chua uống trái cây
# Searching image for: Trà sữa trân châu
# Searching image for: Sinh tố chuối
# Searching image for: Sinh tố xoài
# Searching image for: Nước dừa đóng hộp
# Searching image for: Rượu vang đỏ
# Searching image for: Rượu vang trắng
# Searching image for: Sữa bắp
# Searching image for: Sữa hạt sen
# Searching image for: Sữa yến mạch
# Searching image for: Trà hoa cúc
# Searching image for: Trà lipton
# Searching image for: Cao lầu
# Searching image for: Bánh căn
# Searching image for: Bánh bèo
# Searching image for: Bánh nậm
# Searching image for: Bún hến
# Searching image for: Cơm hến
# Searching image for: Chả ram bắp
# Searching image for: Bánh tráng cuốn thịt heo
# Searching image for: Bánh đập
# Searching image for: Gỏi cá Nam Ô
# Searching image for: Bún chả cá
# Searching image for: Bánh canh chả cá
# Searching image for: Bún mắm nêm
# Searching image for: Nem lụi
# Searching image for: Bánh hỏi thịt nướng
# Searching image for: Chè hạt sen
# Searching image for: Chè đậu ván
# Searching image for: Cơm tấm sườn bì chả
# Searching image for: Hủ tiếu Nam Vang
# Searching image for: Gỏi cuốn
# Searching image for: Chả giò
# Searching image for: Lẩu mắm
# Searching image for: Cá kho tộ
# Searching image for: Canh chua cá
# Searching image for: Thịt kho tàu
# Searching image for: Gà nướng muối ớt
# Searching image for: Bánh tét
# Searching image for: Bánh tráng trộn
# Searching image for: Chè ba màu
# Searching image for: Bánh lọt
# Searching image for: Chè bưởi
# Searching image for: Bánh chuối hấp
# Searching image for: Bánh cam
# Searching image for: Bún chả
# Searching image for: Bún thang
# Searching image for: Chả cá Lã Vọng
# Searching image for: Nem rán (chả giò)
# Searching image for: Xôi xéo
# Searching image for: Xôi gà
# Searching image for: Bánh đa cua
# Searching image for: Cơm lam
# Searching image for: Bánh đúc
# Searching image for: Bánh gai
# Searching image for: Bánh gio
# Searching image for: Bánh khúc
# Searching image for: Bún mọc
# Searching image for: Chè kho
# Searching image for: Chè đậu xanh
# Searching image for: Chè sen
# Searching image for: Thịt đông
# Searching image for: Giò lụa
# Searching image for: Giò thủ
# Searching image for: Thịt nướng
# Searching image for: Thịt luộc
# Searching image for: Cá kho
# Searching image for: Lẩu gà
# Searching image for: Lẩu riêu cua
# Searching image for: Miến lươn
# Searching image for: Cháo sườn
# Searching image for: Cháo trai
# Searching image for: Cháo gà
# Searching image for: Xôi ngô
# Searching image for: Bún nước lèo
# Searching image for: Bún cá
# Searching image for: Bánh tằm bì
# Searching image for: Bánh pía
# Searching image for: Cháo cá lóc
# Searching image for: Cá lóc nướng trui
# Searching image for: Lẩu cá kèo
# Searching image for: Lẩu cua đồng
# Searching image for: Bánh canh Trảng Bàng
# Searching image for: Hủ tiếu Mỹ Tho
# Searching image for: Hủ tiếu Sa Đéc
# Searching image for: Nem nướng Cái Răng
# Searching image for: Bánh ít lá gai
# Searching image for: Bánh tét lá cẩm
# Searching image for: Thắng cố
# Searching image for: Lợn cắp nách nướng
# Searching image for: Xôi ngũ sắc
# Searching image for: Gà đồi nướng mắc khén
# Searching image for: Pa pỉnh tộp (cá nướng)
# Searching image for: Nậm pịa
# Searching image for: Lạp xưởng gác bếp
# Searching image for: Trâu gác bếp
# Searching image for: Bê chao
# Searching image for: Rêu đá nướng
# Searching image for: Măng chua nấu thịt
# Searching image for: Canh bon
# Searching image for: Nộm hoa ban
# Searching image for: Bánh ngải
# Searching image for: Chẩm chéo
# Searching image for: Thịt trâu nướng mắc khén
# Searching image for: Thịt lợn muối chua
# Searching image for: Cá suối nướng
# Searching image for: Chè Shan tuyết
# Searching image for: Cháo ấu tẩu
# Searching image for: Phở chua Lạng Sơn
# Searching image for: Khâu nhục
# Searching image for: Lợn quay Lạng Sơn
# Searching image for: Bánh cuốn Cao Bằng
# Searching image for: Bánh khảo
# Searching image for: Bánh coóng phù
# Searching image for: Bánh tẻ
# Searching image for: Vịt quay 7 vị
# Searching image for: Xôi trám
# Searching image for: Thịt trâu gác bếp
# Searching image for: Măng nhồi thịt
# Searching image for: Canh gà lá giang
# Searching image for: Canh cá nấu măng chua
# Searching image for: Bún ốc
# Searching image for: Miến ngan
# Searching image for: Nộm bò khô
# Searching image for: Thịt chua
# Searching image for: Nộm hoa chuối
# Searching image for: Cá nướng mắc khén
# Searching image for: Gà hấp lá chanh
# Searching image for: Bánh trứng kiến
# Searching image for: Nộm rau muống
# Searching image for: Canh chua cá lóc
# Searching image for: Cá nướng
# Searching image for: Tôm rang muối
# Searching image for: Tôm hấp
# Searching image for: Tôm nướng
# Searching image for: Mực nướng
# Searching image for: Mực xào chua ngọt
# Searching image for: Mực chiên giòn
# Searching image for: Lẩu mực
# Searching image for: Súp cua
# Searching image for: Cua rang me
# Searching image for: Cua hấp
# Searching image for: Sò huyết xào tỏi
# Searching image for: Nghêu hấp sả
# Searching image for: Hàu nướng mỡ hành
# Searching image for: Gỏi sứa
# Searching image for: Gỏi cá trích
# Searching image for: Cháo hải sản
# Searching image for: Bún hải sản
# Searching image for: Lẩu hải sản
# Searching image for: Gỏi tôm
# Searching image for: Gỏi mực
# Searching image for: Cá thu kho
# Searching image for: Sò điệp nướng phô mai
# Searching image for: Bánh canh ghẹ
# Searching image for: Cháo tôm
# Searching image for: Cháo mực
# Searching image for: Bún cá ngừ
# Searching image for: Cá bống kho tộ
# Searching image for: Cơm chiên hải sản
# Searching image for: Bánh xèo hải sản
# Searching image for: Cháo vịt
# Searching image for: Cháo hến
# Searching image for: Cháo cá
# Searching image for: Cháo bò
# Searching image for: Cháo lươn
# Searching image for: Cháo ếch
# Searching image for: Cháo ngao
# Searching image for: Cháo gạo lứt
# Searching image for: Cháo thịt bằm
# Searching image for: Cháo đậu xanh
# Searching image for: Cháo bí đỏ
# Searching image for: Cháo yến mạch
# Searching image for: Cháo hành
# Searching image for: Cháo thịt gà ác
# Searching image for: Cháo gà rau củ
# Searching image for: Cháo dinh dưỡng trẻ em
# Searching image for: Cháo thịt nạc bằm
# Searching image for: Cháo chim bồ câu
# Searching image for: Cháo vịt bắc thảo
# Searching image for: Cháo cua
# Searching image for: Cháo sườn non
# Searching image for: Cháo bắp
# Searching image for: Cháo đậu đen
# Searching image for: Cháo trắng
# Searching image for: Cháo trứng
# Searching image for: Cháo thịt viên
# Searching image for: Súp gà
# Searching image for: Súp tôm
# Searching image for: Súp măng tây
# Searching image for: Súp ngô (bắp)
# Searching image for: Súp lươn
# Searching image for: Súp bò viên
# Searching image for: Súp cá
# Searching image for: Súp rau củ
# Searching image for: Súp nấm
# Searching image for: Súp cua biển
# Searching image for: Súp hải sản
# Searching image for: Súp bí đỏ
# Searching image for: Súp bào ngư
# Searching image for: Súp đậu xanh
# Searching image for: Súp khoai tây
# Searching image for: Súp chay
# Searching image for: Súp cà chua
# Searching image for: Súp cải bó xôi
# Searching image for: Súp đậu Hà Lan
# Searching image for: Súp tôm cua
# Searching image for: Súp bí đỏ hải sản
# Searching image for: Súp gà ngô
# Searching image for: Súp gà nấm hương
# Searching image for: Súp nấm chay
# Searching image for: Súp tôm chua cay
# Searching image for: Súp hoành thánh
# Searching image for: Súp gà rau củ
# Searching image for: Súp hạt sen
# Searching image for: Súp thập cẩm
# Searching image for: Gỏi bò
# Searching image for: Gỏi gà
# Searching image for: Gỏi ngó sen tôm thịt
# Searching image for: Gỏi hoa chuối
# Searching image for: Gỏi đu đủ
# Searching image for: Gỏi bưởi tôm thịt
# Searching image for: Gỏi xoài
# Searching image for: Gỏi hải sản
# Searching image for: Gỏi gà xé phay
# Searching image for: Gỏi bò khô
# Searching image for: Gỏi tai heo
# Searching image for: Gỏi tôm xoài xanh
# Searching image for: Gỏi vịt
# Searching image for: Gỏi cuốn thịt nướng
# Searching image for: Gỏi chân gà rút xương
# Searching image for: Gỏi rau muống
# Searching image for: Gỏi tai heo tôm thịt
# Searching image for: Gỏi bắp chuối tôm thịt
# Searching image for: Gỏi bắp cải tím tôm thịt
# Searching image for: Gỏi bạch tuộc
# Searching image for: Gỏi bò tái chanh
# Searching image for: Gỏi đu đủ tôm thịt
# Searching image for: Gỏi măng cụt tôm thịt
# Searching image for: Gỏi cuốn lụa
# Searching image for: Trứng gà
# Searching image for: Trứng vịt
# Searching image for: Trứng bắc thảo
# Searching image for: Trứng ngỗng
# Searching image for: Trứng đà điểu
# Searching image for: Tỏi
# Searching image for: Hành tím
# Searching image for: Gừng
# Searching image for: Sả
# Searching image for: Ớt đỏ
# Searching image for: Hạt tiêu đen
# Searching image for: Mắm tôm
# Searching image for: Nước mắm
# Searching image for: Bột ngọt (MSG)
# Searching image for: Đường trắng
# Searching image for: Đường nâu
# Searching image for: Muối ăn
# Searching image for: Bột nêm
# Searching image for: Nước tương
# Searching image for: Tương ớt
# Searching image for: Tương cà
# Searching image for: Dầu hào
# Searching image for: Dầu ăn
# Searching image for: Giấm

# %%
food_df = pd.DataFrame(food_list)
food_df.head()
# Out:
#             food_name serving_size calories fat sugar protein fiber  \
# 0   Gỏi cuốn tôm thịt        1 Cái      160   2    15       8     1
# 1  Bánh mì thịt nướng      1 ổ vừa      460  12    50      18     3
# 2     Bún đậu mắm tôm       1 phần      700  22    75      20     5
# 3      Bún chả Hà Nội       1 phần      650  20    60      25     4
# 4           Mì xào Bò        1 đĩa      650  18    65      22     4
#
#                                              img_src
# 0  https://cdn.tgdd.vn/2021/08/CookRecipe/Avatar/...
# 1  https://www.bigc.vn/files/cam-nang-mua-sam-27-...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://vcdn1-giadinh.vnecdn.net/2021/01/08/An...
# 4  https://cdn.tgdd.vn/2021/03/CookProduct/miaobo...

# %%
food_df.isna().sum()
# Out:
# food_name       0
# serving_size    0
# calories        0
# fat             0
# sugar           0
# protein         0
# fiber           0
# img_src         0
# dtype: int64

# %%
food_df.to_csv('food.csv', index=False)

# %%
def upload_to_azure(row):
    cleaned_name = clean_name(row['food_name'])
    image_name = f'{cleaned_name}.jpg'
    for i in range(3):
        try:
            azure_src = upload_img_by_url(image_name, row['img_src'])
            break
        except Exception as e:
            print(f"Retrying... {e}")
            time.sleep(2)
    return azure_src

# %%
food_df['azure_img_src'] = food_df.apply(upload_to_azure, axis=1)
# Out:
# Upload Gỏi_cuốn_tôm_thịt.jpg
# Upload Bánh_mì_thịt_nướng.jpg
# Upload Bún_đậu_mắm_tôm.jpg
# Upload Bún_chả_Hà_Nội.jpg
# Upload Mì_xào_Bò.jpg
# Upload Sữa_tươi_trân_châu_đường_đen.jpg
# Upload Trà_Sữa.jpg
# Upload KimBap.jpg
# Upload Trứng_vịt_lộn.jpg
# Upload Củ_sắn.jpg
# Upload Mận_đỏ.jpg
# Upload Thanh_long.jpg
# Upload Ổi.jpg
# Upload Vú_sữa.jpg
# Upload Mít_sấy.jpg
# Upload Chuối_sấy.jpg
# Upload Cam.jpg
# Upload Đậu_phộng_chiên_muối.jpg
# Upload Đậu_phộng_rang.jpg
# Upload Sơ_ri.jpg
# Upload Nho_ta_tím.jpg
# Upload Hồng_đỏ.jpg
# Upload Đu_đủ.jpg
# Upload Đậu_phộng_da_cá.jpg
# Upload Đậu_phộng_nấu.jpg
# Upload Khoai_lang_chiên.jpg
# Upload Khoai_tây.jpg
# Upload Khế.jpg
# Upload Mãng_cầu_xiêm.jpg
# Upload Bắp_nướng.jpg
# Upload Bắp_luộc.jpg
# Upload Táo_tây.jpg
# Upload Khoai_mì.jpg
# Upload Khoai_từ.jpg
# Upload Lê.jpg
# Upload Bắp_xào.jpg
# Upload Khoai_lang.jpg
# Upload Bưởi.jpg
# Upload Mãng_cầu_ta.jpg
# Upload Dưa_hấu.jpg
# Upload Chuối_già.jpg
# Upload Khoai_môn.jpg
# Upload Nho_Mỹ_đỏxanh.jpg
# Upload Cóc.jpg
# Upload Nho_khô.jpg
# Upload Quýt.jpg
# Upload Hạt_điều.jpg
# Upload Chuối_khô.jpg
# Upload Sầu_riêng.jpg
# Upload Măng_cụt.jpg
# Upload Chôm_chôm.jpg
# Upload Vải_đóng_hộp.jpg
# Upload Mít_nghệ.jpg
# Upload Mít_tố_nữ.jpg
# Upload Táo_ta.jpg
# Upload Nhãn_thường.jpg
# Upload Nhãn_tiêu.jpg
# Upload Xoài.jpg
# Upload Thơm.jpg
# Upload Chuối_sứ.jpg
# Upload Chuối_cau.jpg
# Upload Bơ.jpg
# Upload Trái_dừa_tươi.jpg
# Upload Thạch_dừa.jpg
# Upload Sữa_hộp_Cô_gái_Hà_lan.jpg
# Upload Sữa_đậu_nành_Tribeco.jpg
# Upload Sữa_đặc_có_đường.jpg
# Upload Sữa_chua_Yoghurt_Vinamilk.jpg
# Upload Sữa_chua_uống_YoMost.jpg
# Upload Sinh_tố.jpg
# Upload Phô_mai_Bò_cười.jpg
# Upload Nước_sâm.jpg
# Upload Nước_rau_má.jpg
# Upload Nước_ngọt_có_gaz.jpg
# Upload Nước_mía.jpg
# Upload Nước_ép_trái_cây_đóng_hộp.jpg
# Upload Nước_chanh.jpg
# Upload Nước_cam_vắt.jpg
# Upload Kem_hộp.jpg
# Upload Kem_Cornetto.jpg
# Upload Kem_cây_KidoWall.jpg
# Upload Chôm_chôm_đóng_hộp.jpg
# Upload Cocktail_trái_cây.jpg
# Upload Cà_phê_sữa_gói_tan.jpg
# Upload Cà_phê_đen_phin.jpg
# Upload Bia.jpg
# Upload Trứng_vịt_luộc.jpg
# Upload Trứng_vịt_bắc_thảo.jpg
# Upload Trứng_gà_ta.jpg
# Upload Trứng_gà_Mỹ.jpg
# Upload Trứng_cút.jpg
# Upload Hột_vịt_muối.jpg
# Upload Hột_vịt_lộn.jpg
# Upload Xôi_vò.jpg
# Upload Xôi_vị.jpg
# Upload Xôi_nếp_than.jpg
# Upload Xôi_mặn.jpg
# Upload Xôi_lá_cẩm.jpg
# Upload Xôi_khúc_cúc.jpg
# Upload Xôi_gấc.jpg
# Upload Xôi_đậu_xanh.jpg
# Upload Xôi_đậu_phộng.jpg
# Upload Xôi_đậu_đen.jpg
# Upload Xôi_bắp.jpg
# Upload Sâm_bổ_lượng.jpg
# Upload Chè_trôi_nước.jpg
# Upload Chè_thưng.jpg
# Upload Chè_thạch_nhãn.jpg
# Upload Chè_táo_xọn.jpg
# Upload Chè_nếp_khoai_môn.jpg
# Upload Chè_nếp_đậu_trắng.jpg
# Upload Chè_đậu_xanh_phổ_tai.jpg
# Upload Chè_đậu_xanh_đánh.jpg
# Upload Chè_đậu_trắng.jpg
# Upload Chè_đậu_đen.jpg
# Upload Chè_chuối_chưng.jpg
# Upload Chè_bắp.jpg
# Upload Bắp_giã.jpg
# Upload Kẹo_trái_cây.jpg
# Upload Kẹo_sữa.jpg
# Upload Kẹo_dừa.jpg
# Upload Kẹo_dẻo.jpg
# Upload Kẹo_chocolate_nhân_đậu_phộng.jpg
# Upload Há_cảo.jpg
# Upload Giò_cháo_quẩy.jpg
# Upload Bánh_xèo.jpg
# Upload Bánh_ướt.jpg
# Upload Bánh_tiêu.jpg
# Upload Bánh_tét_nhân_mặn.jpg
# Upload Bánh_tét_nhân_đậu_ngọt.jpg
# Upload Bánh_tét_nhân_chuối.jpg
# Upload Bánh_sừng_trâu.jpg
# Upload Bánh_su_kem.jpg
# Upload Bánh_snack.jpg
# Upload Bánh_quy_bơ_biscuit.jpg
# Retrying... HTTPSConnectionPool(host='dacsanmuicamau.com', port=443): Max retries exceeded with url: /static/product/2018/0911/banh-phong-tom-ca-mau-950.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)')))
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
#     739 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 741 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742     sock=sock,
#     743     cert_reqs=self.cert_reqs,
#     744     ssl_version=self.ssl_version,
#     745     ssl_minimum_version=self.ssl_minimum_version,
#     746     ssl_maximum_version=self.ssl_maximum_version,
#     747     ca_certs=self.ca_certs,
#     748     ca_cert_dir=self.ca_cert_dir,
#     749     ca_cert_data=self.ca_cert_data,
#     750     cert_file=self.cert_file,
#     751     key_file=self.key_file,
#     752     key_password=self.key_password,
#     753     server_hostname=server_hostname_rm_dot,
#     754     ssl_context=self.ssl_context,
#     755     tls_in_tls=tls_in_tls,
#     756     assert_hostname=self.assert_hostname,
#     757     assert_fingerprint=self.assert_fingerprint,
#     758 )
#     759 self.sock = sock_and_verified.socket
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\connection.py:920, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     918         server_hostname = normalized
# --> 920 ssl_sock = ssl_wrap_socket(
#     921     sock=sock,
#     922     keyfile=key_file,
#     923     certfile=cert_file,
#     924     key_password=key_password,
#     925     ca_certs=ca_certs,
#     926     ca_cert_dir=ca_cert_dir,
#     927     ca_cert_data=ca_cert_data,
#     928     server_hostname=server_hostname,
#     929     ssl_context=context,
#     930     tls_in_tls=tls_in_tls,
#     931 )
#     933 try:
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\util\ssl_.py:460, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     458 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 460 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     461 return ssl_sock
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\util\ssl_.py:504, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     502     return SSLTransport(sock, ssl_context, server_hostname)
# --> 504 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File C:\Program Files\Python311\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File C:\Program Files\Python311\Lib\ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#
# File C:\Program Files\Python311\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='dacsanmuicamau.com', port=443): Max retries exceeded with url: /static/product/2018/0911/banh-phong-tom-ca-mau-950.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Cell In[16], line 6, in upload_to_azure(row)
#       5 try:
# ----> 6     azure_src = upload_img_by_url(image_name, row['img_src'])
#       7     break
#
# File f:\PersonalProjects\Hackathon-2025\DE\azure_helper.py:27, in upload_img_by_url(image_name, image_url)
#      26 def upload_img_by_url(image_name, image_url):
# ---> 27     image_data = requests.get(image_url).content
#      28     container_client.upload_blob(name=image_name, data=io.BytesIO(image_data), overwrite=True)
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)     70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\requests\adapters.py:517, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515 if isinstance(e.reason, _SSLError):
#     516     # This branch is for urllib3 v1.22 and later.
# --> 517     raise SSLError(e, request=request)
#     519 raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='dacsanmuicamau.com', port=443): Max retries exceeded with url: /static/product/2018/0911/banh-phong-tom-ca-mau-950.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1002)')))
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 food_df['azure_img_src'] = food_df.apply(upload_to_azure, axis=1)
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)  10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File f:\PersonalProjects\Hackathon-2025\DE\venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[16], line 10, in upload_to_azure(row)
#       8     except Exception as e:
#       9         print(f"Retrying... {e}")
# ---> 10         sleep(2)
#      11 return azure_src
#
# NameError: name 'sleep' is not defined
